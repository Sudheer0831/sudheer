# %%
import pandas as pd

# %%
df=pd.read_csv("mental_health_workplace_survey.csv")

# %%
df.head()#for first 5 data in table
# Out:
#    EmployeeID  Age      Gender    Country            JobRole Department  \
# 0        1001   50        Male         UK    Sales Associate         HR
# 1        1002   36        Male    Germany  Software Engineer         IT
# 2        1003   29  Non-binary      India           IT Admin         IT
# 3        1004   42        Male  Australia      HR Specialist         IT
# 4        1005   40        Male     Brazil   Customer Support    Support
#
#    YearsAtCompany  WorkHoursPerWeek RemoteWork  BurnoutLevel  ...  \
# 0              14                47         No          3.37  ...
# 1               1                59     Hybrid          7.39  ...
# 2              13                59     Hybrid          7.10  ...
# 3              15                31        Yes          4.18  ...
# 4               6                34        Yes          8.28  ...
#
#    CommuteTime  HasMentalHealthSupport  ManagerSupportScore  HasTherapyAccess  \
# ...

# %%
df.shape
# Out:
# (3000, 25)

# %%
df.isnull().sum() # gives the sum of missing data in dataframe
# Out:
# EmployeeID                0
# Age                       0
# Gender                    0
# Country                   0
# JobRole                   0
# Department                0
# YearsAtCompany            0
# WorkHoursPerWeek          0
# RemoteWork                0
# BurnoutLevel              0
# JobSatisfaction           0
# StressLevel               0
# ProductivityScore         0
# SleepHours                0
# PhysicalActivityHrs       0
# CommuteTime               0
# HasMentalHealthSupport    0
# ManagerSupportScore       0
# HasTherapyAccess          0
# MentalHealthDaysOff       0
# SalaryRange               0
# WorkLifeBalanceScore      0
# TeamSize                  0
# CareerGrowthScore         0
# BurnoutRisk               0
# dtype: int64

# %%
num_cols = df.select_dtypes(include='number').columns  
for col in num_cols:
    median_val = df[col].median()
    df[col] = df[col].fillna(median_val)
    cat_cols = df.select_dtypes(include='object').columns   
for col in cat_cols:
    mode_val = df[col].mode()[0]
    df[col] = df[col].fillna(mode_val)

# %%
df.head()
# Out:
#    EmployeeID  Age      Gender    Country            JobRole Department  \
# 0        1001   50        Male         UK    Sales Associate         HR
# 1        1002   36        Male    Germany  Software Engineer         IT
# 2        1003   29  Non-binary      India           IT Admin         IT
# 3        1004   42        Male  Australia      HR Specialist         IT
# 4        1005   40        Male     Brazil   Customer Support    Support
#
#    YearsAtCompany  WorkHoursPerWeek RemoteWork  BurnoutLevel  ...  \
# 0              14                47         No          3.37  ...
# 1               1                59     Hybrid          7.39  ...
# 2              13                59     Hybrid          7.10  ...
# 3              15                31        Yes          4.18  ...
# 4               6                34        Yes          8.28  ...
#
#    CommuteTime  HasMentalHealthSupport  ManagerSupportScore  HasTherapyAccess  \
# ...

# %%
df['workHoursPerDay'] = df['WorkHoursPerWeek'] / 7    #we are creating a new column-work HoursPerDay
df['workHoursPerDay']
# Out:
# 0       6.714286
# 1       8.428571
# 2       8.428571
# 3       4.428571
# 4       4.857143
#           ...
# 2995    6.571429
# 2996    4.428571
# 2997    5.428571
# 2998    5.857143
# 2999    6.857143
# Name: workHoursPerDay, Length: 3000, dtype: float64

# %%
df['Worked'] = df['workHoursPerDay'] >8
df['Worked'].value_counts()
# Out:
# Worked
# False    2732
# True      268
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    EmployeeID  Age      Gender    Country            JobRole Department  \
# 0        1001   50        Male         UK    Sales Associate         HR
# 1        1002   36        Male    Germany  Software Engineer         IT
# 2        1003   29  Non-binary      India           IT Admin         IT
# 3        1004   42        Male  Australia      HR Specialist         IT
# 4        1005   40        Male     Brazil   Customer Support    Support
#
#    YearsAtCompany  WorkHoursPerWeek RemoteWork  BurnoutLevel  ...  \
# 0              14                47         No          3.37  ...
# 1               1                59     Hybrid          7.39  ...
# 2              13                59     Hybrid          7.10  ...
# 3              15                31        Yes          4.18  ...
# 4               6                34        Yes          8.28  ...
#
#    ManagerSupportScore  HasTherapyAccess  MentalHealthDaysOff  SalaryRange  \
# ...

# %%
median_workhours = df['workHoursPerDay'].median()
df['workHoursPerDay'] = df['workHoursPerDay'].apply(lambda x: median_workhours if x > 8 else x)

# %%
(df['workHoursPerDay'] > 8).sum()
# Out:
# np.int64(0)
